# %%
from dataloader import HypersimDataset

# %%
loader = HypersimDataset(csv_file="data/train_data.csv", data_path = "./data/")

# %%
img, depth, semseg = loader.__getitem__(1)

# %%
import matplotlib.pyplot as plt
plt.imshow(img.permute(1, 2, 0), interpolation="bicubic")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img, depth, semseg = loader.__getitem__(1)

# %%
import numpy as np
x = 0 
F = 0
max_print = 5
running = True
while running: 
    img, depth, semseg = loader.__getitem__(x)
    if np.isnan(np.sum(depth.numpy())): 
        plt.imshow(depth.numpy(), interpolation="bicubic")
        plt.title(f"{F} Default Depth")
        plt.show()
        plt.imshow(img.permute(1, 2, 0), interpolation="bicubic")
        plt.title(f"{F} Default Image")
        plt.show()
        y = depth.numpy()
        y = np.nan_to_num(y, nan=500)
        plt.imshow(y)
        plt.title(f"{F} NaN Mask")
        plt.show()
        if F == 4: 
            running = False
        F += 1
    x += 1
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
